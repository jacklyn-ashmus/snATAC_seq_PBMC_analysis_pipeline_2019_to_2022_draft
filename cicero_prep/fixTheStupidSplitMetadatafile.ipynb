# %%
inputfilename = '/nfs/lab/jnewsome/pbmc/cicero_v3/debug/old_pbmc1_12/pbmc1to12.cluster_labels_v6_afterDoublet9_macroGroups.B-cell.txt'
outputfilename = '/nfs/lab/jnewsome/pbmc/cicero_v3/debug/old_pbmc1_12/pbmc1to12.cluster_labels_v6_afterDoublet9_macroGroups.B-cell.headerFix.txt'

# %%
headerLine = 'barcodes\tsample\tleiden\tsubcluster\tfine_populations\tbroad_populations\tfine_populations_long\tbroad_populations_long\tUMAP1\tUMAP2\tunique_usable_reads\ttotal_sequenced_reads\tduplicated_reads\tunique_mito_reads\treads_in_peaks\treads_in_promoters\ttss_used\tfrac_reads_in_peaks\tfrac_reads_in_promoters\tfrac_promoters_used\tfrac_mito_reads\tfrac_duplicated_reads\tlog10_unique_usable_reads\tn_counts\tlog10_usable_counts\tnorm\n'

# %%
headerLine = 'barcodes\tUMAP1\tUMAP2\tLeiden\tCell\n'

# %%
lineList = list()
infile = open(inputfilename)

for line in infile:
    line = line.strip()
    if len(line) > 0:
        lineList.append(line)
        
infile.close()

outfile = open(outputfilename, 'w')


outfile.write(headerLine)

for line in lineList:
    outfile.write(line + '\n')
    
    
outfile.close()
