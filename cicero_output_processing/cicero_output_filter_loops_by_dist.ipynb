# %%
cellTypes = ['b']


inputfileprefix = '/nfs/lab/jnewsome/pbmc/cicero_v3/ciceroOut_mergeCounts/pbmc1-15.b.chr10.cicero_conns.txt'
inputfilesuffix = ''

# %%
conns from last week 50880713 total
conns from this week 41468851 total

# %%
35478591 total

# %%
29937643 / 35478591
# Out:
# 0.8438227718795259

# %%
29937643 / 2
# Out:
# 14968821.5
